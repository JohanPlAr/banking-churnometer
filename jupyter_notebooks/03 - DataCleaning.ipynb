# %% [markdown]
# # Data Cleaning Notebook

# %% [markdown]
# ## Objectives
#
# *   Evaluate missing data
# *   Clean data
#
# ## Inputs
#
# * outputs/datasets/collection/bank_customer_churn.csv
#
# ## Outputs
#
# * Generate cleaned Train and Test sets, both saved under outputs/datasets/cleaned
#
# ## Conclusions
#
#
#   * Data Cleaning Pipeline
#   * Drop Variables:  `['RowNumber','CustomerId', 'Surname', 'HasCrCard ]`

# %% [markdown]
# ---

# %% [markdown]
# # Change working directory

# %% [markdown]
# We need to change the working directory from its current folder to its parent folder
# * We access the current directory with os.getcwd()

# %%
import os
current_dir = os.getcwd()
current_dir
# Out:
# '/home/joplar/banking-churnometer/jupyter_notebooks'

# %% [markdown]
# We want to make the parent of the current directory the new current directory
# * os.path.dirname() gets the parent directory
# * os.chir() defines the new current directory

# %%
os.chdir(os.path.dirname(current_dir))
print("You set a new current directory")
# Out:
# You set a new current directory

# %% [markdown]
# Confirm the new current directory

# %%
current_dir = os.getcwd()
current_dir
# Out:
# '/home/joplar/banking-churnometer'

# %% [markdown]
# ---

# %% [markdown]
# # Load Collected data

# %%
import pandas as pd
df_raw_path = "outputs/datasets/collection/bank_customer_churn.csv"
df = pd.read_csv(df_raw_path).drop(['RowNumber','CustomerId','Surname'], axis=1)
df.head(3)
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France       1   42       2       0.00              1
# 1          608     Spain       1   41       1   83807.86              1
# 2          502    France       1   42       8  159660.80              3
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1

# %% [markdown]
# Change Categorical values to ints to improve correlation study

# %%
df['Geography'] = df['Geography'].replace({"France":0, "Spain":1, "Germany":2})
df['Gender'] = df['Gender'].replace({"Female":1, "Male":0})
df['TenureByAge'] = df['Tenure']/df['Age']

# %% [markdown]
# # Data Exploration

# %% [markdown]
# In Data Cleaning you are interested to check the distribution and shape of a variable with missing data.

# %%
vars_with_missing_data = df.columns[df.isna().sum() > 0].to_list()
vars_with_missing_data
# Out:
# []

# %%
from ydata_profiling import ProfileReport
if vars_with_missing_data:
    profile = ProfileReport(df=df[vars_with_missing_data], minimal=True)
    profile.to_notebook_iframe()
else:
    print("There are no variables with missing data")
# Out:
# There are no variables with missing data

# %% [markdown]
# # Correlation and PPS Analysis

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ppscore as pps


def heatmap_corr(df, threshold, figsize=(20, 12), font_annot=8):
    if len(df.columns) > 1:
        mask = np.zeros_like(df, dtype=np.bool)
        mask[np.triu_indices_from(mask)] = True
        mask[abs(df) < threshold] = True

        fig, axes = plt.subplots(figsize=figsize)
        sns.heatmap(df, annot=True, xticklabels=True, yticklabels=True,
                    mask=mask, cmap='viridis', annot_kws={"size": font_annot}, ax=axes,
                    linewidth=0.5
                    )
        axes.set_yticklabels(df.columns, rotation=0)
        plt.ylim(len(df.columns), 0)
        plt.show()


def heatmap_pps(df, threshold, figsize=(20, 12), font_annot=8):
    if len(df.columns) > 1:
        mask = np.zeros_like(df, dtype=np.bool)
        mask[abs(df) < threshold] = True
        fig, ax = plt.subplots(figsize=figsize)
        ax = sns.heatmap(df, annot=True, xticklabels=True, yticklabels=True,
                         mask=mask, cmap='rocket_r', annot_kws={"size": font_annot},
                         linewidth=0.05, linecolor='grey')
        plt.ylim(len(df.columns), 0)
        plt.show()


def CalculateCorrAndPPS(df):
    df_corr_spearman = df.corr(method="spearman")
    df_corr_pearson = df.corr(method="pearson")

    pps_matrix_raw = pps.matrix(df)
    pps_matrix = pps_matrix_raw.filter(['x', 'y', 'ppscore']).pivot(columns='x', index='y', values='ppscore')

    pps_score_stats = pps_matrix_raw.query("ppscore < 1").filter(['ppscore']).describe().T
    print("PPS threshold - check PPS score IQR to decide threshold for heatmap \n")
    print(pps_score_stats.round(3))

    return df_corr_pearson, df_corr_spearman, pps_matrix


def DisplayCorrAndPPS(df_corr_pearson, df_corr_spearman, pps_matrix, CorrThreshold, PPS_Threshold,
                      figsize=(20, 12), font_annot=8):

    print("\n")
    print("* Analyse how the target variable for your ML models are correlated with other variables (features and target)")
    print("* Analyse multi-colinearity, that is, how the features are correlated among themselves")

    print("\n")
    print("*** Heatmap: Spearman Correlation ***")
    print("It evaluates monotonic relationship \n")
    heatmap_corr(df=df_corr_spearman, threshold=CorrThreshold, figsize=figsize, font_annot=font_annot)

    print("\n")
    print("*** Heatmap: Pearson Correlation ***")
    print("It evaluates the linear relationship between two continuous variables \n")
    heatmap_corr(df=df_corr_pearson, threshold=CorrThreshold, figsize=figsize, font_annot=font_annot)

    print("\n")
    print("*** Heatmap: Power Predictive Score (PPS) ***")
    print(f"PPS detects linear or non-linear relationships between two columns.\n"
          f"The score ranges from 0 (no predictive power) to 1 (perfect predictive power) \n")
    heatmap_pps(df=pps_matrix, threshold=PPS_Threshold, figsize=figsize, font_annot=font_annot)

# %% [markdown]
# Calculate Correlations and Power Predictive Score

# %%
df_corr_pearson, df_corr_spearman, pps_matrix = CalculateCorrAndPPS(df)
# Out:
# PPS threshold - check PPS score IQR to decide threshold for heatmap
#
#          count   mean    std  min  25%  50%  75%    max
# ppscore  306.0  0.045  0.155  0.0  0.0  0.0  0.0  0.999

# %% [markdown]
# Display at Heatmaps

# %%
DisplayCorrAndPPS(df_corr_pearson = df_corr_pearson,
                  df_corr_spearman = df_corr_spearman, 
                  pps_matrix = pps_matrix,
                  CorrThreshold = 0.1, PPS_Threshold =0.005,
                  figsize=(12,10), font_annot=10)
# Out:
# * Analyse how the target variable for your ML models are correlated with other variables (features and target)
# * Analyse multi-colinearity, that is, how the features are correlated among themselves
#
#
# *** Heatmap: Spearman Correlation ***
# It evaluates monotonic relationship
# *** Heatmap: Pearson Correlation ***
# It evaluates the linear relationship between two continuous variables
# *** Heatmap: Power Predictive Score (PPS) ***
# PPS detects linear or non-linear relationships between two columns.
# The score ranges from 0 (no predictive power) to 1 (perfect predictive power)

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Assessing Missing Data Levels

# %% [markdown]
# * Custom function to display missing data levels in a DataFrame, it shows the absolute levels, relative levels and data type.

# %%
def EvaluateMissingData(df):
    missing_data_absolute = df.isnull().sum()
    missing_data_percentage = round(missing_data_absolute/len(df)*100, 2)
    df_missing_data = (pd.DataFrame(
                            data={"RowsWithMissingData": missing_data_absolute,
                                   "PercentageOfDataset": missing_data_percentage,
                                   "DataType": df.dtypes}
                                    )
                          .sort_values(by=['PercentageOfDataset'], ascending=False)
                          .query("PercentageOfDataset > 0")
                          )

    return df_missing_data

# %% [markdown]
# Check missing data levels for the collected dataset.

# %%
EvaluateMissingData(df)
# Out:
# Empty DataFrame
# Columns: [RowsWithMissingData, PercentageOfDataset, DataType]
# Index: []

# %% [markdown]
# ## Data Cleaning Spreadsheet Summary

# %% [markdown]
# * Consider your spreadsheet notes on potential approaches to handle missing data

# %% [markdown]
# ## Dealing with Missing Data

# %% [markdown]
# This dataset doesn't require much data cleaning, therefore we are not loading the DataCleaningEffect() function we studied in the feature-engine lesson.
# * For your future projects, this would be a moment to load that function and use it over your data-cleaning process.
# * For this project, we are skipping this part.

# %% [markdown]
# ### Data Cleaning Summary

# %% [markdown]
# List here the data cleaning approaches you want initially to try.
# * Drop - `['RowNumber','CustomerId', 'Surname']`
#
#
# **The list above is your guide, your map to know at which stage you are in the data-cleaning process**

# %% [markdown]
# ### Split Train and Test Set

# %%
from sklearn.model_selection import train_test_split
TrainSet, TestSet, _, __ = train_test_split(
                                        df,
                                        df['Exited'],
                                        test_size=0.2,
                                        random_state=0)

print(f"TrainSet shape: {TrainSet.shape} \nTestSet shape: {TestSet.shape}")
# Out:
# TrainSet shape: (8000, 11)
# TestSet shape: (2000, 11)

# %%
df_missing_data = EvaluateMissingData(TrainSet)
print(f"* There are {df_missing_data.shape[0]} variables with missing data \n")
df_missing_data
# Out:
# * There are 0 variables with missing data
# Empty DataFrame
# Columns: [RowsWithMissingData, PercentageOfDataset, DataType]
# Index: []

# %% [markdown]
# ### Drop Variables

# %% [markdown]
# * Hint: you may drop Variables with more than 80% of missing data since these variables will likely not add much value. However, this is not the case in this dataset
# * Step 1: imputation approach: **Drop Variables**
# * Step 2: Select variables to apply the imputation approach

# %%
variables_method = ['RowNumber', 'CustomerId', 'Surname']

print(f"* {len(variables_method)} variables to drop \n\n"
    f"{variables_method}")
# Out:
# * 3 variables to drop
#
# ['RowNumber', 'CustomerId', 'Surname']

# %% [markdown]
# * We are dropping `CustomerId` since it is a unique identifier for each customer, it doesn't add information to the dataset as it is.
# * We are dropping `SurName` since it is close to being a unique identifier for each customer.
# * We are dropping `RowNumber` since it is a unique identifier for each row/customer and doesn't add information to the dataset as it is.

# %% [markdown]
# * Step 3: Create a separate DataFrame applying this imputation approach to the selected variables.

# %%
from feature_engine.selection import DropFeatures
imputer = DropFeatures(features_to_drop=variables_method)
imputer.fit(TrainSet)
df_method = imputer.transform(TrainSet)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 from feature_engine.selection import DropFeatures
# ----> 2 imputer = DropFeatures(features_to_drop=variables_method)
#       3 imputer.fit(TrainSet)
#       4 df_method = imputer.transform(TrainSet)
#
# NameError: name 'variables_method' is not defined

# %% [markdown]
# * Step 4: Assess the effect on the variable's distribution.

# %% [markdown]
# * In this case, there is no effect on the distribution of the variable, since you are not removing rows, but columns.
# * The effect might be losing features that might have a relevant impact on your machine-learning model.

# %% [markdown]
# * Step 5: If you are satisfied, apply the transformation to your data.

# %%
from feature_engine.selection import DropFeatures
imputer = DropFeatures(features_to_drop=variables_method)
imputer.fit(TrainSet)

TrainSet, TestSet = imputer.transform(TrainSet) , imputer.transform(TestSet)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[104], line 3
#       1 from feature_engine.selection import DropFeatures
#       2 imputer = DropFeatures(features_to_drop=variables_method)
# ----> 3 imputer.fit(TrainSet)
#       5 TrainSet, TestSet = imputer.transform(TrainSet) , imputer.transform(TestSet)
#
# File ~/.pyenv/versions/3.8.18/lib/python3.8/site-packages/feature_engine/selection/drop_features.py:68, in DropFeatures.fit(self, X, y)
#      64 X = _is_dataframe(X)
#      66 # X[self.features_to_drops] calls to pandas to check if columns are
#      67 # present in the df.
# ---> 68 X[self.features_to_drop]
#      70 self.features_to_drop_ = self.features_to_drop
#      72 # check user is not removing all columns in the dataframe
#
# File ~/.pyenv/versions/3.8.18/lib/python3.8/site-packages/pandas/core/frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File ~/.pyenv/versions/3.8.18/lib/python3.8/site-packages/pandas/core/indexes/base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5782 self._raise_if_missing(keyarr, indexer, axis_name)
#    5784 keyarr = self.take(indexer)
#    5785 if isinstance(key, Index):
#    5786     # GH 42790 - Preserve name from an Index
#
# File ~/.pyenv/versions/3.8.18/lib/python3.8/site-packages/pandas/core/indexes/base.py:5842, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5840     if use_interval_msg:
#    5841         key = list(key)
# -> 5842     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5844 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    5845 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['RowNumber', 'CustomerId', 'Surname'], dtype='object')] are in the [columns]"

# %% [markdown]
# * Step 6: Evaluate if you have more variables to deal with. If yes, iterate. If not, you are done.

# %%
EvaluateMissingData(TrainSet)
# Out:
# Empty DataFrame
# Columns: [RowsWithMissingData, PercentageOfDataset, DataType]
# Index: []

# %% [markdown]
# # Create Cleaned Data Folder

# %%
import os
try:
  os.makedirs(name='outputs/datasets/cleaned') # create outputs/datasets/collection folder
except Exception as e:
  print(e)

# %% [markdown]
# ## Train Set

# %%
TrainSet.to_csv("outputs/datasets/cleaned/TrainSetCleaned.csv", index=False)

# %% [markdown]
# ## Test Set

# %%
TestSet.to_csv("outputs/datasets/cleaned/TestSetCleaned.csv", index=False)
