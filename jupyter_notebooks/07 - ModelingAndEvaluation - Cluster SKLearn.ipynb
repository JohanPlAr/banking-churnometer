# %% [markdown]
# # Cluster

# %% [markdown]
# ## Objectives
#
# * Fit and evaluate a cluster model to group similar data
# * Understand the profile for each cluster
#
#
# ## Inputs
#
# * outputs/datasets/collection/bank-customer-churn.csv
# * Instructions on which variables to use for data cleaning and feature engineering. They are found in their respective notebooks.
#
# ## Outputs
#
# * Cluster Pipeline
# * Train Set
# * Most important features to define a cluster plot
# * Clusters Profile Description
# * Cluster Silhouette

# %% [markdown]
# ---

# %% [markdown]
# # Change working directory

# %% [markdown]
# We need to change the working directory from its current folder to its parent folder
# * We access the current directory with os.getcwd()

# %%
import os
current_dir = os.getcwd()
current_dir
# Out:
# '/home/joplar/banking-churnometer/jupyter_notebooks'

# %% [markdown]
# We want to make the parent of the parent of current directory the new current directory
# * os.path.dirname() gets the parent directory
# * os.chir() defines the new current directory

# %%
os.chdir(os.path.dirname(current_dir))
print("You set a new current directory")
# Out:
# You set a new current directory

# %% [markdown]
# Confirm the new current directory

# %%
current_dir = os.getcwd()
current_dir
# Out:
# '/home/joplar/banking-churnometer'

# %% [markdown]
# ---

# %% [markdown]
# # Load Data

# %%
import pandas as pd
df = (pd.read_csv("outputs/datasets/collection/bank-customer-churn.csv")
      .drop(['CustomerId', 'RowNumber', 'Surname','Exited'], axis=1)
      )
print(df.shape)
df.head(3)
# Out:
# (10000, 10)
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1        101348.88
# 1          0               1        112542.58
# 2          1               0        113931.57

# %% [markdown]
# # Cluster Pipeline with all data

# %% [markdown]
# ##  ML Cluster Pipeline

# %%
from sklearn.pipeline import Pipeline

# Feature Engineering
from feature_engine.encoding import OrdinalEncoder
from feature_engine.selection import SmartCorrelatedSelection
from feature_engine import transformation as vt
from feature_engine.outliers import Winsorizer

# Feat Scaling
from sklearn.preprocessing import StandardScaler

# PCA
from sklearn.decomposition import PCA

# ML algorithm
from sklearn.cluster import KMeans


def PipelineCluster():
    pipeline_base = Pipeline([
        ("boxcox", vt.BoxCoxTransformer(variables=['Age'])),
        ("Winsorizer", Winsorizer(capping_method='iqr', tail='both', fold=1.5, variables=['Age','CreditScore'])),
        ("OrdinalCategoricalEncoder", OrdinalEncoder(encoding_method='arbitrary', variables=['Gender','Geography'])),
        ("SmartCorrelatedSelection", SmartCorrelatedSelection(variables=None,
         method="spearman", threshold=0.6, selection_method="variance")),

        ("scaler", StandardScaler()),

        ("PCA", PCA(n_components=50, random_state=0)),

        ("model", KMeans(n_clusters=50, random_state=0)),


    ])
    return pipeline_base

# %% [markdown]
# ## Principal Component Analysis (PCA)

# %%
pipeline_cluster = PipelineCluster()
pipeline_pca = Pipeline(pipeline_cluster.steps[:-2])
df_pca = pipeline_pca.fit_transform(df)

print(df_pca.shape,'\n', type(df_pca))
# Out:
# (10000, 10)
#  <class 'numpy.ndarray'>

# %% [markdown]
# Apply PCA separately to the scaled data

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")

n_components = 10


def pca_components_analysis(df_pca, n_components):
    pca = PCA(n_components=n_components).fit(df_pca)
    x_PCA = pca.transform(df_pca)  # array with transformed PCA

    ComponentsList = ["Component " + str(number)
                      for number in range(n_components)]
    dfExplVarRatio = pd.DataFrame(
        data=np.round(100 * pca.explained_variance_ratio_, 3),
        index=ComponentsList,
        columns=['Explained Variance Ratio (%)'])

    dfExplVarRatio['Accumulated Variance'] = dfExplVarRatio['Explained Variance Ratio (%)'].cumsum(
    )

    PercentageOfDataExplained = dfExplVarRatio['Explained Variance Ratio (%)'].sum(
    )

    print(
        f"* The {n_components} components explain {round(PercentageOfDataExplained,2)}% of the data \n")
    plt.figure(figsize=(9, 6))
    sns.lineplot(data=dfExplVarRatio,  marker="o")
    plt.xticks(rotation=90)
    plt.yticks(np.arange(0, 110, 10))
    plt.show()


pca_components_analysis(df_pca=df_pca, n_components=n_components)
# Out:
# * The 10 components explain 100.0% of the data

# %%
pca_components_analysis(df_pca=df_pca,n_components=6)
# Out:
# * The 6 components explain 66.2% of the data

# %%
def PipelineCluster():
    pipeline_base = Pipeline([
        ("boxcox", vt.BoxCoxTransformer(variables=['Age'])),
        ("Winsorizer", Winsorizer(capping_method='iqr', tail='both', fold=1.5, variables=['Age','CreditScore'])),
        ("OrdinalCategoricalEncoder", OrdinalEncoder(encoding_method='arbitrary', variables=['Gender','Geography'])),
        ("SmartCorrelatedSelection", SmartCorrelatedSelection(variables=None,
         method="spearman", threshold=0.6, selection_method="variance")),

        ("scaler", StandardScaler()),

        # we update n_components to 7
        ("PCA", PCA(n_components=7, random_state=0)),

        ("model", KMeans(n_clusters=50, random_state=0)),


    ])
    return pipeline_base


PipelineCluster()
# Out:
# Pipeline(steps=[('boxcox', BoxCoxTransformer(variables=['Age'])),
#                 ('Winsorizer',
#                  Winsorizer(capping_method='iqr', fold=1.5, tail='both',
#                             variables=['Age', 'CreditScore'])),
#                 ('OrdinalCategoricalEncoder',
#                  OrdinalEncoder(encoding_method='arbitrary',
#                                 variables=['Gender', 'Geography'])),
#                 ('SmartCorrelatedSelection',
#                  SmartCorrelatedSelection(method='spearman',
#                                           selection_method='variance',
#                                           threshold=0.6)),
#                 ('scaler', StandardScaler()),
#                 ('PCA', PCA(n_components=7, random_state=0)),
#                 ('model', KMeans(n_clusters=50, random_state=0))])

# %% [markdown]
# ## Elbow Method and Silhouette Score

# %%
pipeline_cluster = PipelineCluster()
pipeline_analysis = Pipeline(pipeline_cluster.steps[:-1])
df_analysis = pipeline_analysis.fit_transform(df)

print(df_analysis.shape,'\n', type(df_analysis))
# Out:
# (10000, 7)
#  <class 'numpy.ndarray'>

# %%
from yellowbrick.cluster import KElbowVisualizer

visualizer = KElbowVisualizer(KMeans(random_state=0), k=(1,11)) # 11 is not inclusive, it will plot until 10
visualizer.fit(df_analysis) 
visualizer.show() 
plt.show()

# %%
from yellowbrick.cluster import SilhouetteVisualizer

# 6 is not inclusive, it will stop at 5
n_cluster_start, n_cluster_stop = 2, 6

print("=== Average Silhouette Score for different number of clusters ===")
visualizer = KElbowVisualizer(KMeans(random_state=0), k=(
    n_cluster_start, n_cluster_stop), metric='silhouette')
visualizer.fit(df_analysis)
visualizer.show()
plt.show()
print("\n")


for n_clusters in np.arange(start=n_cluster_start, stop=n_cluster_stop):

    print(f"=== Silhouette plot for {n_clusters} Clusters ===")
    visualizer = SilhouetteVisualizer(estimator=KMeans(n_clusters=n_clusters, random_state=0),
                                      colors='yellowbrick')
    visualizer.fit(df_analysis)
    visualizer.show()
    plt.show()
    print("\n")
# Out:
# === Average Silhouette Score for different number of clusters ===
# === Silhouette plot for 2 Clusters ===
# === Silhouette plot for 3 Clusters ===
# === Silhouette plot for 4 Clusters ===
# === Silhouette plot for 5 Clusters ===

# %%
def PipelineCluster():
    pipeline_base = Pipeline([
           ("boxcox", vt.BoxCoxTransformer(variables=['Age'])),
        ("Winsorizer", Winsorizer(capping_method='iqr', tail='both', fold=1.5, variables=['Age','CreditScore'])),
        ("OrdinalCategoricalEncoder", OrdinalEncoder(encoding_method='arbitrary', variables=['Gender','Geography'])),
        ("SmartCorrelatedSelection", SmartCorrelatedSelection(variables=None,
         method="spearman", threshold=0.6, selection_method="variance")),
         
        ("scaler", StandardScaler()),

        ("PCA", PCA(n_components=6, random_state=0)),

        # we update n_clusters to 3
        ("model", KMeans(n_clusters=3, random_state=0)),


    ])
    return pipeline_base


PipelineCluster()
# Out:
# Pipeline(steps=[('boxcox', BoxCoxTransformer(variables=['Age'])),
#                 ('Winsorizer',
#                  Winsorizer(capping_method='iqr', fold=1.5, tail='both',
#                             variables=['Age', 'CreditScore'])),
#                 ('OrdinalCategoricalEncoder',
#                  OrdinalEncoder(encoding_method='arbitrary',
#                                 variables=['Gender', 'Geography'])),
#                 ('SmartCorrelatedSelection',
#                  SmartCorrelatedSelection(method='spearman',
#                                           selection_method='variance',
#                                           threshold=0.6)),
#                 ('scaler', StandardScaler()),
#                 ('PCA', PCA(n_components=6, random_state=0)),
#                 ('model', KMeans(n_clusters=3, random_state=0))])

# %% [markdown]
# ## Fit Cluster Pipeline

# %% [markdown]
# Quick recap of our data for training cluster pipeline

# %%
X = df.copy()
print(X.shape)
X.head(3)
# Out:
# (10000, 10)
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1        101348.88
# 1          0               1        112542.58
# 2          1               0        113931.57

# %% [markdown]
# Fit Cluster pipeline

# %%
pipeline_cluster = PipelineCluster()
pipeline_cluster.fit(X)
# Out:
# Pipeline(steps=[('boxcox', BoxCoxTransformer(variables=['Age'])),
#                 ('Winsorizer',
#                  Winsorizer(capping_method='iqr', fold=1.5, tail='both',
#                             variables=['Age', 'CreditScore'])),
#                 ('OrdinalCategoricalEncoder',
#                  OrdinalEncoder(encoding_method='arbitrary',
#                                 variables=['Gender', 'Geography'])),
#                 ('SmartCorrelatedSelection',
#                  SmartCorrelatedSelection(method='spearman',
#                                           selection_method='variance',
#                                           threshold=0.6,
#                                           variables=['CreditScore', 'Geography',
#                                                      'Gender', 'Age', 'Tenure',
#                                                      'Balance', 'NumOfProducts',
#                                                      'HasCrCard',
#                                                      'IsActiveMember',
#                                                      'EstimatedSalary'])),
#                 ('scaler', StandardScaler()),
#                 ('PCA', PCA(n_components=6, random_state=0)),
#                 ('model', KMeans(n_clusters=3, random_state=0))])

# %% [markdown]
# ## Add cluster predictions to dataset

# %% [markdown]
# We add a column "`Clusters`" (with the cluster pipeline predictions) to the dataset

# %%
X['Clusters'] = pipeline_cluster['model'].labels_
print(X.shape)
X.head(3)
# Out:
# (10000, 11)
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Clusters
# 0          1               1        101348.88         0
# 1          0               1        112542.58         1
# 2          1               0        113931.57         0

# %%
print(f"* Clusters frequencies \n{ X['Clusters'].value_counts(normalize=True).to_frame().round(2)} \n\n")
X['Clusters'].value_counts().sort_values().plot(kind='bar')
plt.show()
# Out:
# * Clusters frequencies
#    Clusters
# 0      0.37
# 1      0.33
# 2      0.31

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("whitegrid")
plt.figure(figsize=(10, 6))
sns.scatterplot(x=df_analysis[:, 0], y=df_analysis[:, 1],
                hue=X['Clusters'], palette='Set1', alpha=0.6)
plt.scatter(x=pipeline_cluster['model'].cluster_centers_[:, 0], y=pipeline_cluster['model'].cluster_centers_[:, 1],
            marker="x", s=169, linewidths=3, color="black")
plt.xlabel("PCA Component 0")
plt.ylabel("PCA Component 1")
plt.title("PCA Components colored by Clusters")
plt.show()

# %% [markdown]
# We save the cluster predictions from this pipeline to use in the future. We will get back to that in a later stage.

# %%
cluster_predictions_with_all_variables = X['Clusters']
cluster_predictions_with_all_variables
# Out:
# 0       0
# 1       1
# 2       0
# 3       0
# 4       2
#        ..
# 9995    0
# 9996    1
# 9997    0
# 9998    2
# 9999    1
# Name: Clusters, Length: 10000, dtype: int32

# %% [markdown]
# ## Fit a classifier, where the target is cluster predictions and features remaining variables

# %% [markdown]
# We copy `X` to a DataFrame `df_clf`

# %%
df_clf = X.copy()
print(df_clf.shape)
df_clf.head(3)
# Out:
# (10000, 11)
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Clusters
# 0          1               1        101348.88         0
# 1          0               1        112542.58         1
# 2          1               0        113931.57         0

# %% [markdown]
# Split Train and Test sets

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    df_clf.drop(['Clusters'], axis=1),
    df_clf['Clusters'],
    test_size=0.2,
    random_state=0
)

print(X_train.shape, X_test.shape)
# Out:
# (8000, 10) (2000, 10)

# %% [markdown]
# Create classifier pipeline steps

# %%
# Feat Selection
from sklearn.feature_selection import SelectFromModel

# ML algorithm
from sklearn.ensemble import GradientBoostingClassifier


def PipelineClf2ExplainClusters():
    pipeline_base = Pipeline([
        ("boxcox", vt.BoxCoxTransformer(variables=['Age'])),
        ("Winsorizer", Winsorizer(capping_method='iqr', tail='both', fold=1.5, variables=['Age','CreditScore'])),
        ("OrdinalCategoricalEncoder", OrdinalEncoder(encoding_method='arbitrary', variables=['Gender','Geography'])),
        ("SmartCorrelatedSelection", SmartCorrelatedSelection(variables=None,
         method="spearman", threshold=0.6, selection_method="variance")),
        ("scaler", StandardScaler()),

        ("feat_selection", SelectFromModel(
            GradientBoostingClassifier(random_state=0))),

        ("model", GradientBoostingClassifier(random_state=0)),

    ])
    return pipeline_base


PipelineClf2ExplainClusters()
# Out:
# Pipeline(steps=[('boxcox', BoxCoxTransformer(variables=['Age'])),
#                 ('Winsorizer',
#                  Winsorizer(capping_method='iqr', fold=1.5, tail='both',
#                             variables=['Age', 'CreditScore'])),
#                 ('OrdinalCategoricalEncoder',
#                  OrdinalEncoder(encoding_method='arbitrary',
#                                 variables=['Gender', 'Geography'])),
#                 ('SmartCorrelatedSelection',
#                  SmartCorrelatedSelection(method='spearman',
#                                           selection_method='variance',
#                                           threshold=0.6)),
#                 ('scaler', StandardScaler()),
#                 ('feat_selection',
#                  SelectFromModel(estimator=GradientBoostingClassifier(random_state=0))),
#                 ('model', GradientBoostingClassifier(random_state=0))])

# %% [markdown]
# Fit the classifier to the training data

# %%
pipeline_clf_cluster = PipelineClf2ExplainClusters()
pipeline_clf_cluster.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('boxcox', BoxCoxTransformer(variables=['Age'])),
#                 ('Winsorizer',
#                  Winsorizer(capping_method='iqr', fold=1.5, tail='both',
#                             variables=['Age', 'CreditScore'])),
#                 ('OrdinalCategoricalEncoder',
#                  OrdinalEncoder(encoding_method='arbitrary',
#                                 variables=['Gender', 'Geography'])),
#                 ('SmartCorrelatedSelection',
#                  SmartCorrelatedSelection(method='spearman',
#                                           selection_method='variance',
#                                           threshold=0.6,
#                                           variables=['CreditScore', 'Geography',
#                                                      'Gender', 'Age', 'Tenure',
#                                                      'Balance', 'NumOfProducts',
#                                                      'HasCrCard',
#                                                      'IsActiveMember',
#                                                      'EstimatedSalary'])),
#                 ('scaler', StandardScaler()),
#                 ('feat_selection',
#                  SelectFromModel(estimator=GradientBoostingClassifier(random_state=0))),
#                 ('model', GradientBoostingClassifier(random_state=0))])

# %% [markdown]
# ## Evaluate classifier performance on Train and Test Sets

# %%
from sklearn.metrics import classification_report
print(classification_report(y_train, pipeline_clf_cluster.predict(X_train)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97      2953
#            1       0.86      0.87      0.87      2618
#            2       0.87      0.88      0.87      2429
#
#     accuracy                           0.91      8000
#    macro avg       0.90      0.90      0.90      8000
# weighted avg       0.91      0.91      0.91      8000

# %%
print(classification_report(y_test, pipeline_clf_cluster.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.94      0.96       703
#            1       0.84      0.85      0.84       639
#            2       0.87      0.88      0.87       658
#
#     accuracy                           0.89      2000
#    macro avg       0.89      0.89      0.89      2000
# weighted avg       0.89      0.89      0.89      2000

# %% [markdown]
# ## Assess the most important Features that define a cluster

# %%
# after data cleaning and feature engineering, the feature space changes

# how many data cleaning and feature engineering steps does your pipeline have?
data_cleaning_feat_eng_steps = 2
columns_after_data_cleaning_feat_eng = (Pipeline(pipeline_clf_cluster.steps[:data_cleaning_feat_eng_steps])
                                        .transform(X_train)
                                        .columns)

best_features = columns_after_data_cleaning_feat_eng[pipeline_clf_cluster['feat_selection'].get_support(
)].to_list()

# create DataFrame to display feature importance
df_feature_importance = (pd.DataFrame(data={
    'Feature': columns_after_data_cleaning_feat_eng[pipeline_clf_cluster['feat_selection'].get_support()],
    'Importance': pipeline_clf_cluster['model'].feature_importances_})
    .sort_values(by='Importance', ascending=False)
)

# reassign best features in importance order
best_features = df_feature_importance['Feature'].to_list()

# Most important features statement and plot
print(f"* These are the {len(best_features)} most important features in descending order. "
      f"The model was trained on them: \n{best_features} \n")
df_feature_importance.plot(kind='bar', x='Feature', y='Importance')
plt.show()
# Out:
# * These are the 4 most important features in descending order. The model was trained on them:
# ['Balance', 'Geography', 'NumOfProducts', 'Gender']

# %% [markdown]
# We will store the best_features to use at a later stage.

# %%
best_features_pipeline_all_variables = best_features
best_features_pipeline_all_variables
# Out:
# ['Balance', 'Geography', 'NumOfProducts', 'Gender']

# %% [markdown]
# ## Cluster Analysis

# %% [markdown]
# Load function that plots a table with description for all Clusters

# %%
def DescriptionAllClusters(df, decimal_points=3):

    DescriptionAllClusters = pd.DataFrame(
        columns=df.drop(['Clusters'], axis=1).columns)
    # iterate on each cluster , calls Clusters_IndividualDescription()
    for cluster in df.sort_values(by='Clusters')['Clusters'].unique():

        EDA_ClusterSubset = df.query(
            f"Clusters == {cluster}").drop(['Clusters'], axis=1)
        ClusterDescription = Clusters_IndividualDescription(
            EDA_ClusterSubset, cluster, decimal_points)
        DescriptionAllClusters = DescriptionAllClusters.append(
            ClusterDescription)

    DescriptionAllClusters.set_index(['Cluster'], inplace=True)
    return DescriptionAllClusters


def Clusters_IndividualDescription(EDA_Cluster, cluster, decimal_points):

    ClustersDescription = pd.DataFrame(columns=EDA_Cluster.columns)
    # for a given cluster, iterate over all columns
    # if the variable is numerical, calculate the IQR: display as Q1 -- Q3.
    # That will show the range for the most common values for the numerical variable
    # if the variable is categorical, count the frequencies and displays the top 3 most frequent
    # That will show the most common levels for the category

    for col in EDA_Cluster.columns:

        try:  # eventually a given cluster will have only missing data for a given variable

            if EDA_Cluster[col].dtypes == 'object':

                top_frequencies = EDA_Cluster.dropna(
                    subset=[col])[[col]].value_counts(normalize=True).nlargest(n=3)
                Description = ''

                for x in range(len(top_frequencies)):
                    freq = top_frequencies.iloc[x]
                    category = top_frequencies.index[x][0]
                    CategoryPercentage = int(round(freq*100, 0))
                    statement = f"'{category}': {CategoryPercentage}% , "
                    Description = Description + statement

                ClustersDescription.at[0, col] = Description[:-2]

            elif EDA_Cluster[col].dtypes in ['float', 'int']:
                DescStats = EDA_Cluster.dropna(subset=[col])[[col]].describe()
                Q1 = round(DescStats.iloc[4, 0], decimal_points)
                Q3 = round(DescStats.iloc[6, 0], decimal_points)
                Description = f"{Q1} -- {Q3}"
                ClustersDescription.at[0, col] = Description

        except Exception as e:
            ClustersDescription.at[0, col] = 'Not available'
            print(
                f"** Error Exception: {e} - cluster {cluster}, variable {col}")

    ClustersDescription['Cluster'] = str(cluster)

    return ClustersDescription

# %% [markdown]
# Load a custom function to plot cluster distribution per Variable (absolute and relative levels)

# %%
import plotly.express as px


def cluster_distribution_per_variable(df, target):
    """
    The data should have 2 variables, the cluster predictions and
    the variable you want to analyze with, in this case we call "target".
    We use plotly express to create 2 plots:
    Cluster distribution across the target.
    Relative presence of the target level in each cluster.
    """
    df_bar_plot = df.value_counts(["Clusters", target]).reset_index()
    df_bar_plot.columns = ['Clusters', target, 'Count']
    df_bar_plot[target] = df_bar_plot[target].astype('object')

    print(f"Clusters distribution across {target} levels")
    fig = px.bar(df_bar_plot, x='Clusters', y='Count',
                 color=target, width=800, height=500)
    fig.update_layout(xaxis=dict(tickmode='array',
                      tickvals=df['Clusters'].unique()))
    fig.show(renderer='colab')

    df_relative = (df
                   .groupby(["Clusters", target])
                   .size()
                   .groupby(level=0)
                   .apply(lambda x:  100*x / x.sum())
                   .reset_index()
                   .sort_values(by=['Clusters'])
                   )
    df_relative.columns = ['Clusters', target, 'Relative Percentage (%)']

    print(f"Relative Percentage (%) of {target} in each cluster")
    fig = px.line(df_relative, x='Clusters', y='Relative Percentage (%)',
                  color=target, width=800, height=500)
    fig.update_layout(xaxis=dict(tickmode='array',
                      tickvals=df['Clusters'].unique()))
    fig.update_traces(mode='markers+lines')
    fig.show(renderer='colab')

# %% [markdown]
# Create a DataFrame that contains best features and Clusters Predictions since we want to analyse the patterns for each cluster.

# %%
df_cluster_profile = df_clf.copy()
df_cluster_profile = df_cluster_profile.filter(items=best_features + ['Clusters'], axis=1)
print(df_cluster_profile.shape)
df_cluster_profile.head(5)
# Out:
# (10000, 5)
#      Balance Geography  NumOfProducts  Gender  Clusters
# 0       0.00    France              1  Female         0
# 1   83807.86     Spain              1  Female         1
# 2  159660.80    France              3  Female         0
# 3       0.00    France              2  Female         0
# 4  125510.82     Spain              1  Female         2

# %% [markdown]
# We want also to analyse Churn levels.

# %%
df_churn = pd.read_csv("outputs/datasets/collection/bank-customer-churn.csv").filter(['Exited'])
df_churn['Exited'] = df_churn['Exited'].astype('object')
df_churn.head(5)
# Out:
#   Exited
# 0      1
# 1      0
# 2      1
# 3      0
# 4      0

# %% [markdown]
# ### Cluster profile based on the best features

# %%
pd.set_option('display.max_colwidth', None)
clusters_profile = DescriptionAllClusters(df=pd.concat([df_cluster_profile,df_churn], axis=1), decimal_points=0)
clusters_profile
# Out:
# /tmp/ipykernel_225657/3568331369.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_225657/3568331369.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_225657/3568331369.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
#                       Balance                                       Geography  \
# Cluster
# 0                  0.0 -- 0.0   'France': 71% , 'Spain': 29% , 'Germany': 0%
# 1         87213.0 -- 136556.0  'France': 65% , 'Spain': 25% , 'Germany': 10%
# 2        103516.0 -- 141783.0  'Germany': 71% , 'Spain': 19% , 'France': 10%
#
#         NumOfProducts                        Gender                Exited
# Cluster
# 0          2.0 -- 2.0  'Female': 53% , 'Male': 47%   '0': 86% , '1': 14%
# 1          1.0 -- 1.0  'Male': 79% , 'Female': 21%   '0': 83% , '1': 17%
# 2          1.0 -- 2.0  'Female': 62% , 'Male': 38%   '0': 69% , '1': 31%

# %% [markdown]
# ### Clusters distribution across Churn levels & Relative Percentage of Churn in each cluster

# %%
df_cluster_vs_churn=  df_churn.copy()
df_cluster_vs_churn['Clusters'] = X['Clusters']
cluster_distribution_per_variable(df=df_cluster_vs_churn, target='Exited')
# Out:
# Clusters distribution across Exited levels
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="687c6386-43ea-43d8-9e8e-461c69f213e3" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("687c6386-43ea-43d8-9e8e-461c69f213e3")) {                    Plotly.newPlot(                        "687c6386-43ea-43d8-9e8e-461c69f213e3",                        [{"alignmentgroup": "True", "hovertemplate": "Exited=0<br>Clusters=%{x}<br>Count=%{y}<extra></extra>", "legendgroup": "0", "marker": {"color": "#636efa"}, "name": "0", "offsetgroup": "0", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [0, 1, 2], "xaxis": "x", "y": [3154, 2690, 2119], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Exited=1<br>Clusters=%{x}<br>Count=%{y}<extra></extra>", "legendgroup": "1", "marker": {"color": "#EF553B"}, "name": "1", "offsetgroup": "1", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [2, 1, 0], "xaxis": "x", "y": [968, 567, 502], "yaxis": "y"}],                        {"barmode": "relative", "height": 500, "legend": {"title": {"text": "Exited"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179 ...
# Relative Percentage (%) of Exited in each cluster
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="d6779673-6074-4cf7-830f-c05ef85e90a5" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d6779673-6074-4cf7-830f-c05ef85e90a5")) {                    Plotly.newPlot(                        "d6779673-6074-4cf7-830f-c05ef85e90a5",                        [{"hovertemplate": "Exited=0<br>Clusters=%{x}<br>Relative Percentage (%)=%{y}<extra></extra>", "legendgroup": "0", "line": {"color": "#636efa", "dash": "solid"}, "mode": "markers+lines", "name": "0", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0, 1, 2], "xaxis": "x", "y": [86.2691466083151, 82.59134172551428, 68.64269517330742], "yaxis": "y"}, {"hovertemplate": "Exited=1<br>Clusters=%{x}<br>Relative Percentage (%)=%{y}<extra></extra>", "legendgroup": "1", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "markers+lines", "name": "1", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0, 1, 2], "xaxis": "x", "y": [13.730853391684901, 17.408658274485724, 31.35730482669258], "yaxis": "y"}],                        {"height": 500, "legend": {"title": {"text": "Exited"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.222222222222222 ...

# %% [markdown]
# # Fit New Cluster Pipeline with most important features

# %% [markdown]
# In order to reduce feature space, we will study the trade-off between the previous Cluster Pipeline (fitted with all variables) and Pipeline using the variables that are most important to define the clusters from the previous pipeline

# %%
best_features_pipeline_all_variables
# Out:
# ['Balance', 'Geography', 'NumOfProducts', 'Gender']

# %% [markdown]
# ## Define trade-off and metrics to compare new and previous Cluster Pipeline

# %% [markdown]
# To evaluate this trade-off we will
# 1. Conduct a elbow method and silhouette analysis and check if the same number of clusters is suggested
# 2. Fit new cluster pipeline and compare if the predictions from this pipeline are "equivalent" to the predictions from the previous pipeline
# 3. Fit a classifier to explain cluster, and check if performance on Train and Test sets is similar to the previous pipeline
# 4. Check if the most important features for the classifier are the same from the previous pipeline
# 5. Compare if the cluster profile from both pipelines are "equivalent"
#
# If we are happy to say **yes** for them, we can use a cluster pipeline using the features that best define the clusters from previous pipeline!
# * The **gain** is that in real-time (which is the major purpose of Machine Learning) you will need fewer variables for predicting clusters for your prospects.

# %% [markdown]
# ## Subset data with the most relevant variables

# %%
df_reduced = df.filter(best_features_pipeline_all_variables)
df_reduced.head(3)
# Out:
#      Balance Geography  NumOfProducts  Gender
# 0       0.00    France              1  Female
# 1   83807.86     Spain              1  Female
# 2  159660.80    France              3  Female

# %% [markdown]
# ## Rewrite Cluster Pipeline

# %%
def PipelineCluster():
    pipeline_base = Pipeline([

        # we update the pipeline, considering only the most important variables from the previous pipeline
        ("OrdinalCategoricalEncoder", OrdinalEncoder(encoding_method='arbitrary',
                                                     variables=['Gender','Geography'])),

        # it doesn't need SmartCorrelation

        ("scaler", StandardScaler()),

        # No PCA step needed, since we know which features to consider

        ("model", KMeans(n_clusters=3, random_state=0)),


    ])
    return pipeline_base


PipelineCluster()
# Out:
# Pipeline(steps=[('OrdinalCategoricalEncoder',
#                  OrdinalEncoder(encoding_method='arbitrary',
#                                 variables=['Gender', 'Geography'])),
#                 ('scaler', StandardScaler()),
#                 ('model', KMeans(n_clusters=3, random_state=0))])

# %% [markdown]
# ## Apply Elbow Method and Silhouette analysis

# %%
pipeline_cluster = PipelineCluster()
pipeline_analysis = Pipeline(pipeline_cluster.steps[:-1])
df_analysis = pipeline_analysis.fit_transform(df_reduced)

print(df_analysis.shape,'\n', type(df_analysis))
# Out:
# (10000, 4)
#  <class 'numpy.ndarray'>

# %% [markdown]
# Elbow Analysis

# %%
from yellowbrick.cluster import KElbowVisualizer
visualizer = KElbowVisualizer(KMeans(random_state=0), k=(1,11))
visualizer.fit(df_analysis) 
visualizer.show() 
plt.show()

# %%
from yellowbrick.cluster import SilhouetteVisualizer

n_cluster_start, n_cluster_stop = 2, 6

print("=== Average Silhouette Score for different number of clusters ===")
visualizer = KElbowVisualizer(KMeans(random_state=0), k=(
    n_cluster_start, n_cluster_stop), metric='silhouette')
visualizer.fit(df_analysis)
visualizer.show()
plt.show()
print("\n")


for n_clusters in np.arange(start=n_cluster_start, stop=n_cluster_stop):

    print(f"=== Silhouette plot for {n_clusters} Clusters ===")
    visualizer = SilhouetteVisualizer(estimator=KMeans(n_clusters=n_clusters, random_state=0),
                                      colors='yellowbrick')
    visualizer.fit(df_analysis)
    visualizer.show()
    plt.show()
    print("\n")
# Out:
# === Average Silhouette Score for different number of clusters ===
# /home/joplar/.pyenv/versions/3.8.18/lib/python3.8/site-packages/yellowbrick/utils/kneed.py:155: YellowbrickWarning:
#
# No 'knee' or 'elbow point' detected This could be due to bad clustering, no actual clusters being formed etc.
#
# /home/joplar/.pyenv/versions/3.8.18/lib/python3.8/site-packages/yellowbrick/cluster/elbow.py:343: YellowbrickWarning:
#
# No 'knee' or 'elbow' point detected, pass `locate_elbow=False` to remove the warning
# === Silhouette plot for 2 Clusters ===
# === Silhouette plot for 3 Clusters ===
# === Silhouette plot for 4 Clusters ===
# === Silhouette plot for 5 Clusters ===

# %% [markdown]
# ## Fit New Cluster Pipeline

# %% [markdown]
# We set X as our training set for the cluster. It is a copy of df_reduced

# %%
X = df_reduced.copy()
print(X.shape)
X.head(3)
# Out:
# (10000, 4)
#      Balance Geography  NumOfProducts  Gender
# 0       0.00    France              1  Female
# 1   83807.86     Spain              1  Female
# 2  159660.80    France              3  Female

# %% [markdown]
# Fit Cluster pipeline

# %%
pipeline_cluster = PipelineCluster()
pipeline_cluster.fit(X)
# Out:
# Pipeline(steps=[('OrdinalCategoricalEncoder',
#                  OrdinalEncoder(encoding_method='arbitrary',
#                                 variables=['Gender', 'Geography'])),
#                 ('scaler', StandardScaler()),
#                 ('model', KMeans(n_clusters=3, random_state=0))])

# %% [markdown]
# ## Add cluster predictions to dataset

# %% [markdown]
# We add a column "`Clusters`" (with the cluster pipeline predictions) to the dataset

# %%
X['Clusters'] = pipeline_cluster['model'].labels_
print(X.shape)
X.head(3)
# Out:
# (10000, 5)
#      Balance Geography  NumOfProducts  Gender  Clusters
# 0       0.00    France              1  Female         0
# 1   83807.86     Spain              1  Female         2
# 2  159660.80    France              3  Female         0

# %%
print(f"* Clusters frequencies \n{ X['Clusters'].value_counts(normalize=True).to_frame().round(2)} \n\n")
X['Clusters'].value_counts().sort_values().plot(kind='bar')
plt.show()
# Out:
# * Clusters frequencies
#    Clusters
# 0      0.35
# 1      0.33
# 2      0.32

# %% [markdown]
# ## Compare current cluster predictions to previous cluster predictions

# %% [markdown]
# We just fitted a new cluster pipeline and want to compare if its predictions are "equivalent" to the previous cluster.

# %% [markdown]
# These are the predictions from the **previous** cluster pipeline - trained with all variables

# %%
cluster_predictions_with_all_variables
# Out:
# 0       0
# 1       1
# 2       0
# 3       0
# 4       2
#        ..
# 9995    0
# 9996    1
# 9997    0
# 9998    2
# 9999    1
# Name: Clusters, Length: 10000, dtype: int32

# %% [markdown]
# And these are the predictions from **current** cluster pipeline (trained with `['OnlineBackup', 'MonthlyCharges', 'PhoneService']`)

# %%
cluster_predictions_with_best_features = X['Clusters'] 
cluster_predictions_with_best_features
# Out:
# 0       0
# 1       2
# 2       0
# 3       0
# 4       2
#        ..
# 9995    0
# 9996    1
# 9997    0
# 9998    2
# 9999    1
# Name: Clusters, Length: 10000, dtype: int32

# %% [markdown]
# We use a confusion matrix to evaluate if the predictions of both pipelines are **"equivalent"**

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(cluster_predictions_with_all_variables, cluster_predictions_with_best_features))
# Out:
# [[3425  213   18]
#  [  39 2750  468]
#  [  38  351 2698]]

# %% [markdown]
# ## Fit a classifier, where the target is cluster predictions and features remaining variables

# %%
df_clf = X.copy()
print(df_clf.shape)
df_clf.head(3)
# Out:
# (10000, 5)
#      Balance Geography  NumOfProducts  Gender  Clusters
# 0       0.00    France              1  Female         0
# 1   83807.86     Spain              1  Female         2
# 2  159660.80    France              3  Female         0

# %% [markdown]
# Split Train and Test sets

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    df_clf.drop(['Clusters'], axis=1),
    df_clf['Clusters'],
    test_size=0.2,
    random_state=0
)

print(X_train.shape, X_test.shape)
# Out:
# (8000, 4) (2000, 4)

# %% [markdown]
# Rewrite pipeline to explain clusters

# %%
def PipelineClf2ExplainClusters():
    pipeline_base = Pipeline([

        ("OrdinalCategoricalEncoder", OrdinalEncoder(encoding_method='arbitrary',
                                                     variables=['Gender', 'Geography'])),

        # it doesn't need SmartCorrelation

        ("scaler", StandardScaler()),

        # we don't consider feature selection step, since we know which features to consider

        ("model", GradientBoostingClassifier(random_state=0)),

    ])
    return pipeline_base


PipelineClf2ExplainClusters()
# Out:
# Pipeline(steps=[('OrdinalCategoricalEncoder',
#                  OrdinalEncoder(encoding_method='arbitrary',
#                                 variables=['Gender', 'Geography'])),
#                 ('scaler', StandardScaler()),
#                 ('model', GradientBoostingClassifier(random_state=0))])

# %% [markdown]
# ## Fit a classifier, where the target is cluster labels and features remaining variables

# %% [markdown]
# Create and fit a classifier pipeline to learn the feature importance when defining a cluster

# %%
pipeline_clf_cluster = PipelineClf2ExplainClusters()
pipeline_clf_cluster.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('OrdinalCategoricalEncoder',
#                  OrdinalEncoder(encoding_method='arbitrary',
#                                 variables=['Gender', 'Geography'])),
#                 ('scaler', StandardScaler()),
#                 ('model', GradientBoostingClassifier(random_state=0))])

# %% [markdown]
# ## Evaluate classifier performance on Train and Test Sets

# %%
print(classification_report(y_train, pipeline_clf_cluster.predict(X_train)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2836
#            1       1.00      1.00      1.00      2658
#            2       1.00      1.00      1.00      2506
#
#     accuracy                           1.00      8000
#    macro avg       1.00      1.00      1.00      8000
# weighted avg       1.00      1.00      1.00      8000

# %%
print(classification_report(y_test, pipeline_clf_cluster.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       666
#            1       1.00      1.00      1.00       656
#            2       1.00      1.00      1.00       678
#
#     accuracy                           1.00      2000
#    macro avg       1.00      1.00      1.00      2000
# weighted avg       1.00      1.00      1.00      2000

# %% [markdown]
# ## Assess Most Important Features

# %%
# since we don't have feature selection step in this pipeline, best_features is Xtrain columns
best_features = X_train.columns.to_list()

# create a DataFrame to display feature importance
df_feature_importance = (pd.DataFrame(data={
    'Feature': best_features,
    'Importance': pipeline_clf_cluster['model'].feature_importances_})
    .sort_values(by='Importance', ascending=False)
)

best_features = df_feature_importance['Feature'].to_list()

# Most important features statement and plot
print(f"* These are the {len(best_features)} most important features in descending order. "
      f"The model was trained on them: \n{df_feature_importance['Feature'].to_list()}")

df_feature_importance.plot(kind='bar', x='Feature', y='Importance')
plt.show()
# Out:
# * These are the 4 most important features in descending order. The model was trained on them:
# ['Geography', 'Balance', 'NumOfProducts', 'Gender']

# %% [markdown]
# ## Cluster Analysis

# %% [markdown]
# Create a DataFrame that contains the best features and Clusters Predictions: we want to analyse the patterns for each cluster.

# %%
df_cluster_profile = df_clf.copy()
df_cluster_profile = df_cluster_profile.filter(items=best_features + ['Clusters'], axis=1)
df_cluster_profile.head(3)
# Out:
#   Geography    Balance  NumOfProducts  Gender  Clusters
# 0    France       0.00              1  Female         0
# 1     Spain   83807.86              1  Female         2
# 2    France  159660.80              3  Female         0

# %% [markdown]
# We want also to analyse Churn levels

# %%
df_churn = pd.read_csv("outputs/datasets/collection/bank-customer-churn.csv").filter(['Exited'])
df_churn['Exited'] = df_churn['Exited'].astype('object')
df_churn.head(3)
# Out:
#   Exited
# 0      1
# 1      0
# 2      1

# %% [markdown]
# ### Cluster profile on most important features

# %%
pd.set_option('display.max_colwidth', None)
clusters_profile = DescriptionAllClusters(df= pd.concat([df_cluster_profile,df_churn], axis=1), decimal_points=0)
clusters_profile
# Out:
# /tmp/ipykernel_225657/3568331369.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_225657/3568331369.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /tmp/ipykernel_225657/3568331369.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#                                              Geography               Balance  \
# Cluster
# 0        'France': 69% , 'Spain': 31% , 'Germany': 0%             0.0 -- 0.0
# 1                        'France': 79% , 'Spain': 21%    86481.0 -- 138813.0
# 2                       'Germany': 79% , 'Spain': 21%   102689.0 -- 138651.0
#
#         NumOfProducts                        Gender                Exited
# Cluster
# 0          2.0 -- 2.0  'Female': 55% , 'Male': 45%   '0': 86% , '1': 14%
# 1          1.0 -- 1.0  'Male': 72% , 'Female': 28%   '0': 82% , '1': 18%
# 2          1.0 -- 2.0  'Female': 54% , 'Male': 46%   '0': 70% , '1': 30%

# %% [markdown]
# ### Clusters distribution across Churn levels & Relative Percentage of Churn in each cluster

# %%
df_cluster_vs_churn=  df_churn.copy()
df_cluster_vs_churn['Clusters'] = X['Clusters']
cluster_distribution_per_variable(df=df_cluster_vs_churn, target='Exited')
# Out:
# Clusters distribution across Exited levels
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="24c628ff-4b8c-42b6-a274-5d59289f70d3" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("24c628ff-4b8c-42b6-a274-5d59289f70d3")) {                    Plotly.newPlot(                        "24c628ff-4b8c-42b6-a274-5d59289f70d3",                        [{"alignmentgroup": "True", "hovertemplate": "Exited=0<br>Clusters=%{x}<br>Count=%{y}<extra></extra>", "legendgroup": "0", "marker": {"color": "#636efa"}, "name": "0", "offsetgroup": "0", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [0, 1, 2], "xaxis": "x", "y": [3026, 2708, 2229], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Exited=1<br>Clusters=%{x}<br>Count=%{y}<extra></extra>", "legendgroup": "1", "marker": {"color": "#EF553B"}, "name": "1", "offsetgroup": "1", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [2, 1, 0], "xaxis": "x", "y": [955, 606, 476], "yaxis": "y"}],                        {"barmode": "relative", "height": 500, "legend": {"title": {"text": "Exited"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179 ...
# Relative Percentage (%) of Exited in each cluster
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="403e78f4-a7d9-45cc-918e-7fccd497a203" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("403e78f4-a7d9-45cc-918e-7fccd497a203")) {                    Plotly.newPlot(                        "403e78f4-a7d9-45cc-918e-7fccd497a203",                        [{"hovertemplate": "Exited=0<br>Clusters=%{x}<br>Relative Percentage (%)=%{y}<extra></extra>", "legendgroup": "0", "line": {"color": "#636efa", "dash": "solid"}, "mode": "markers+lines", "name": "0", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0, 1, 2], "xaxis": "x", "y": [86.40776699029126, 81.71394085697042, 70.00628140703517], "yaxis": "y"}, {"hovertemplate": "Exited=1<br>Clusters=%{x}<br>Relative Percentage (%)=%{y}<extra></extra>", "legendgroup": "1", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "markers+lines", "name": "1", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0, 1, 2], "xaxis": "x", "y": [13.592233009708737, 18.286059143029572, 29.993718592964825], "yaxis": "y"}],                        {"height": 500, "legend": {"title": {"text": "Exited"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222 ...

# %% [markdown]
# ## Which pipeline should I deploy?

# %% [markdown]
# Let's recap the criteria we consider to evaluate the **trade-off**
# 1. Conduct an elbow method and silhouette analysis and check if the same number of clusters is suggested.
# 2. Fit a new cluster pipeline and compare if the predictions from this pipeline are "equivalent" to the predictions from the previous pipeline.
# 3. Fit a classifier to explain cluster and check if performance on Train and Test sets is similar to the previous pipeline.
# 4. Check if the most important features for the classifier are the same from the previous pipeline.
# 5. Compare if the cluster profile from both pipelines is "equivalent".

# %%
pipeline_cluster
# Out:
# Pipeline(steps=[('OrdinalCategoricalEncoder',
#                  OrdinalEncoder(encoding_method='arbitrary',
#                                 variables=['OnlineBackup', 'PhoneService'])),
#                 ('scaler', StandardScaler()),
#                 ('model', KMeans(n_clusters=3, random_state=0))])

# %% [markdown]
# # Push files to Repo

# %% [markdown]
# We will generate the following files
#
# * Cluster Pipeline
# * Train Set
# * Feature importance plot
# * Clusters Description
# * Cluster Silhouette

# %%
import joblib
import os

version = 'v1'
file_path = f'outputs/ml_pipeline/cluster_analysis/{version}'

try:
    os.makedirs(name=file_path)
except Exception as e:
    print(e)

# %% [markdown]
# ## Cluster pipeline

# %%
pipeline_cluster
# Out:
# Pipeline(steps=[('OrdinalCategoricalEncoder',
#                  OrdinalEncoder(encoding_method='arbitrary',
#                                 variables=['Gender', 'Geography'])),
#                 ('scaler', StandardScaler()),
#                 ('model', KMeans(n_clusters=3, random_state=0))])

# %%
joblib.dump(value=pipeline_cluster, filename=f"{file_path}/cluster_pipeline.pkl")
# Out:
# ['outputs/ml_pipeline/cluster_analysis/v1/cluster_pipeline.pkl']

# %% [markdown]
# ## Train Set

# %%
print(df_reduced.shape)
df_reduced.head(3)
# Out:
# (10000, 4)
#      Balance Geography  NumOfProducts  Gender
# 0       0.00    France              1  Female
# 1   83807.86     Spain              1  Female
# 2  159660.80    France              3  Female

# %%
df_reduced.to_csv(f"{file_path}/TrainSet.csv", index=False)

# %% [markdown]
# ## Most important features plot

# %% [markdown]
# These are the features that define a cluster

# %%
df_feature_importance.plot(kind='bar',x='Feature',y='Importance', figsize=(8,4))
plt.show()

# %%
df_feature_importance.plot(kind='bar',x='Feature',y='Importance', figsize=(8,4))
plt.savefig(f"{file_path}/features_define_cluster.png", bbox_inches='tight', dpi=150)

# %% [markdown]
# ## Cluster Profile

# %%
clusters_profile
# Out:
#                                              Geography               Balance  \
# Cluster
# 0        'France': 69% , 'Spain': 31% , 'Germany': 0%             0.0 -- 0.0
# 1                        'France': 79% , 'Spain': 21%    86481.0 -- 138813.0
# 2                       'Germany': 79% , 'Spain': 21%   102689.0 -- 138651.0
#
#         NumOfProducts                        Gender                Exited
# Cluster
# 0          2.0 -- 2.0  'Female': 55% , 'Male': 45%   '0': 86% , '1': 14%
# 1          1.0 -- 1.0  'Male': 72% , 'Female': 28%   '0': 82% , '1': 18%
# 2          1.0 -- 2.0  'Female': 54% , 'Male': 46%   '0': 70% , '1': 30%

# %%
clusters_profile.to_csv(f"{file_path}/clusters_profile.csv")

# %% [markdown]
# ## Cluster silhouette plot

# %%
visualizer = SilhouetteVisualizer(Pipeline(pipeline_cluster.steps[-1:])[0] , colors='yellowbrick')
visualizer.fit(df_analysis)
visualizer.show()
plt.show()

# %%
fig, axes = plt.subplots(figsize=(7,5))
fig = SilhouetteVisualizer(Pipeline(pipeline_cluster.steps[-1:])[0] , colors='yellowbrick', ax=axes)
fig.fit(df_analysis)

plt.savefig(f"{file_path}/clusters_silhouette.png", bbox_inches='tight',dpi=150)

# %% [markdown]
# Good job, clear the cell outputs, run git commands to add, commit and push files to the repo. Next, we will move on to create our dashboard!
